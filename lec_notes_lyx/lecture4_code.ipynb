# %% [markdown]
# heteroskedasticity

# %%
n = 100; X = rnorm(n)
u = rnorm(n)
plot( y = u, x = X, col = "blue", ylab = "e")
e = X * rnorm(n)
points( y = e, x = X, col = "red")
# Out:
# plot without title
